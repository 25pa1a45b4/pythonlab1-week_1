# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45b4/pythonlab1-week_1/blob/main/Swap_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input("enter value of a= ")
b=input("enter value of b=")
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# enter value of a= 8
# enter value of b=9
# 9
# 8
